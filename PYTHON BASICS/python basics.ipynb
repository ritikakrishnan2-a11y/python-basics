# %% [markdown]
# ### 1 - PYTHON OUTPUT

# %%
# this prints "Hello world"

print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
print(hello world)
# Out:
#   Cell In[6], line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
hello = 123
print (hello)
# Out:
# 123

# %%
hello_world = 123
print(hello_world)
# Out:
# 123

# %%
print(1)
# Out:
# 1

# %%
1=2
print(1)
# Out:
#   Cell In[12], line 1
#     1=2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
print("7.7")
# Out:
# 7.7

# %%
print(7.7)
# Out:
# 7.7

# %%
Print(7.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Print(7.7)
#
# NameError: name 'Print' is not defined

# %%
Print = 7.7
print(Print)
# Out:
# 7.7

# %%
True == "True"
print(True)
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
print("hello", 1, 7.7, True, sep=",") #put T in capital and word inside quotation
# Out:
# hello,1,7.7,True

# %%
print("Hello", 1, 7.7, True, sep=", ") # put space after comma if you want space in between the terms
# Out:
# Hello, 1, 7.7, True

# %%
print("Hello", end="\n")
print("world")
# Out:
# Hello
# world

# %%
print("Madhu Dadi")
# Out:
# Madhu Dadi

# %%
print(True)
# Out:
# True

# %%
print("Hello World", 1, 4, 7.7, True)
# Out:
# Hello World 1 4 7.7 True

# %%
print('Hello', 1, 4.4, True, sep=',')
# Out:
# Hello,1,4.4,True

# %%
print('Hello', 1, 4.5, True, sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('Madhu')
print('Dadi')
# Out:
# Madhu
# Dadi

# %%
print('Hello', end=' - ')
print('Madhu')
# Out:
# Hello - Madhu

# %%
print('Hello', end=' | ')
print('Madhu')
# Out:
# Hello | Madhu

# %% [markdown]
# ### PRACTICE

# %%
print("4"+"5")
# Out:
# 45

# %%
print(4+"5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(4+"5")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(4+5)
# Out:
# 9

# %%
number = int(input("Enter a 3-digit number: "))
hundreds = number // 100
tens = (number // 10) % 10
units = number % 10
digit_sum = hundreds + tens + units

print("Sum of the digits is:", digit_sum)
# Out:
# Sum of the digits is: 6

# %%
print(hundreds)
# Out:
# 1

# %%
print(number // 10)
# Out:
# 12

# %%
print(number % 10) # how to get remainder - %; how to get quotient - //
# Out:
# 3
